# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt # visyualizing data
# %matplotlib inline
import seaborn as sns

# %%
dff = pd.read_csv("Netflix Dataset.csv")
dff
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
dff.shape
# Out:
# (7789, 11)

# %%
dff.info
# Out:
# <bound method DataFrame.info of      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
dff.isnull
# Out:
# <bound method DataFrame.isnull of      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
type(dff)
# Out:
# pandas.core.frame.DataFrame

# %%
dff.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
# dff.rename(columns={'':'Shaadi'})

# %%
# is there any duplicated

dff[dff.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
# is there any null values

# %%
# for house cards what is the show id  and who is the director

dff[dff["Title"]=="House of Cards"][["Show_Id","Director"]]
# Out:
#      Show_Id                                           Director
# 2832   s2833  Robin Wright, David Fincher, Gerald McRaney, J...

# %%
dff[dff["Title"].str.contains("House of Crads")][["Show_Id","Director"]]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Director]
# Index: []

# %%
dff[dff["Title"].str.contains("House of Cards")][["Show_Id","Director"]]
# Out:
#      Show_Id                                           Director
# 2832   s2833  Robin Wright, David Fincher, Gerald McRaney, J...

# %%
dff["Release_Date"].head(2)
# Out:
# 0      August 14, 2020
# 1    December 23, 2016
# Name: Release_Date, dtype: object

# %%
dff["N_Date"]=pd.to_datetime(dff["Release_Date"],format="mixed")

# %%
dff["N_Date"]
# Out:
# 0      2020-08-14
# 1      2016-12-23
# 2      2018-12-20
# 3      2017-11-16
# 4      2020-01-01
#           ...
# 7784   2020-10-19
# 7785   2019-03-02
# 7786   2020-09-25
# 7787   2020-10-31
# 7788   2020-03-01
# Name: N_Date, Length: 7789, dtype: datetime64[ns]

# %%
[dff["N_Date"].dt.year.value_counts().head(10).plot(kind="barh")]

# %%
# [dff["N_Date"].value_counts().dt.year.head(10).plot(kind="barh")]

# %%
# how many movies and tv shows are in the dataset

dff.Category.value_counts()
# Out:
# Category
# Movie      5379
# TV Show    2410
# Name: count, dtype: int64

# %%
sns.countplot(dff['Category'])
# Out:
# <Axes: xlabel='count', ylabel='Category'>

# %%
sns.countplot(dff.Category.value_counts())
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %%
sns.countplot()
# Out:
# <Axes: >

# %%
# show all the movies that were released in year 2000

dff[(dff["Category"]=="Movie")&(dff["N_Date"].dt.year==2001)]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, N_Date]
# Index: []

# %%
# show only the title of all tv shows that  were released in india only


dff[(dff["Category"]=="TV Show")&(dff["Country"]=="India")]["Title"].sample(5)
# Out:
# 6249             The Creative Indians
# 364                      Akbar Birbal
# 6469           The House That Made Me
# 1729    Devlok with Devdutt Pattanaik
# 4724                  Paava Kadhaigal
# Name: Title, dtype: object

# %%
dff[ (dff["Category"]=="TV Show") &( dff["Country"]=="India")]["Title"].sample(5)
# Out:
# 534           Anjaan: Special Crimes Unit
# 2087    Fabulous Lives of Bollywood Wives
# 2350                    Gangs of Hassepur
# 340                          Agent Raghav
# 5330                     Sab Jholmaal Hai
# Name: Title, dtype: object

# %%
# show top 10 directions, who have highest number of TV Shows movies

dff["Director"].value_counts()
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
#                           ..
# Lucien Jean-Baptiste       1
# Jason Krawczyk             1
# Quinn Lasher               1
# Elle Callahan              1
# Sam Dunn                   1
# Name: count, Length: 4050, dtype: int64

# %%
# show all the records where "Category " is movie and types is comedians or country in UK

dff[(dff["Category"]=="Movie")&(dff["Type"]=="Comedies")|(dff["Country"]=="United Kingdom")]
# Out:
#      Show_Id Category                   Title          Director  \
# 19       s20    Movie                     '89               NaN
# 33       s34    Movie            #realityhigh  Fernando Lebrija
# 58       s59  TV Show             100% Hotter               NaN
# 72       s73    Movie                17 Again       Burr Steers
# 82       s83    Movie     2036 Origin Unknown     Hasraf Dulull
# ...      ...      ...                     ...               ...
# 7670   s7669  TV Show  World War II in Colour               NaN
# 7671   s7670  TV Show  World's Busiest Cities               NaN
# 7688   s7687    Movie  XV: Beyond the Tryline  Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu       James Brown
# 7740   s7739  TV Show         Young Wallander               NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %%
### in how many movies shows , tom criuse 

dff[dff["Cast"]=="Tom Cruise"]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, N_Date]
# Index: []

# %%
dff[dff["Cast"].fillna("").str.contains("Tom Cruise")]["Title"]
# Out:
# 3860    Magnolia
# 5071    Rain Man
# Name: Title, dtype: object

# %%
# what are the different ratings defined by netflix

dff["Rating"].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
dff["Rating"].nunique()
# Out:
# 14

# %%
# how many movies got the "TV 14" rating?

dff[(dff["Category"]=="Movie" ) & (dff["Rating"]=="TV-14" ) & (dff["Country"]=="Canada")].shape[0]
# Out:
# 11

# %%
# how many TV show got the R rating after year 2018



dff[(dff["Category"]=="TV Show" ) & (dff["Rating"]=="R" ) & (dff["N_Date"].dt.year > 2018)]
# Out:
#      Show_Id Category                                Title           Director  \
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country  \
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#         Release_Date Rating  Duration      Type  \
# 6437  April 25, 2019      R  1 Season  TV Shows
#
#                                             Description     N_Date
# 6437  Trapped at a stagecoach stop as a storm rages ... 2019-04-25
